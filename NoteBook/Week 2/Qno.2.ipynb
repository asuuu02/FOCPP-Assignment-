# %%
celsius = float(input("Enter a temperature in Celsius: "))
# Out:
# Enter a temperature in Celsius:  28

# %%
fahrenheit = (celsius * 9/5) + 32

# %%
print(f"{celsius} C is equivalent to {fahrenheit} F.")
# Out:
# 28.0 C is equivalent to 82.4 F.
