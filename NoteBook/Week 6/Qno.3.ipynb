# %%
def is_prime(n):
    
    if n <= 1:
        return False  
    if n == 2:
        return True  
    if n % 2 == 0:
        return False 

    for i in range(3, int(n**0.5)+1, 2):
        if n % i == 0:
            return False
    return True

# %%
test_numbers = [1, 2, 3, 4, 5, 16, 17, 19, 20]

for num in test_numbers:
    print(f"{num} is prime? {is_prime(num)}")
# Out:
# 1 is prime? False
# 2 is prime? True
# 3 is prime? True
# 4 is prime? False
# 5 is prime? True
# 16 is prime? False
# 17 is prime? True
# 19 is prime? True
# 20 is prime? False

# %%
user_input = input("Enter an integer to check if it is prime: ")

try:
    n = int(user_input)
    if is_prime(n):
        print(f"{n} is a prime number.")
    else:
        print(f"{n} is not a prime number.")
except ValueError:
    print("Invalid input! Please enter a valid integer.")
# Out:
# Enter an integer to check if it is prime:  76
# 76 is not a prime number.
