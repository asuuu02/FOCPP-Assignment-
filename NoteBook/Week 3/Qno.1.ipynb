# %%
name = input("Hello, what is your name? ")
# Out:
# Hello, what is your name?  Asuka

# %%
if name == "":
    print("Hello, Stranger!")
else:
    print(f"Hello, {name}. Good to meet you!")
# Out:
# Hello, Asuka. Good to meet you!
