# %% [markdown]
# WEEK 4 Qno.1

# %%
def check_number(num):
    if num >= 0 and num <= 100:
        return True
    else:
        return False

# %%
number = int(input("Enter an integer: "))

answer = check_number(number)

print(answer)
# Out:
# Enter an integer:  55
# True
