# %%
def remove_last_character(text):

    if len(text) > 1:
        return text[:-1]   
    else:
        return text

# %%
user_input = input("Enter a string: ")

result = remove_last_character(user_input)

print("Result:", result)
# Out:
# Enter a string:  helloo everyone
# Result: helloo everyon
