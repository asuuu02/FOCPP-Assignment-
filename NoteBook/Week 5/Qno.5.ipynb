# %%
import statistics

# %%
temperatures = []

print("Enter temperatures in Celsius (e.g., 25C). Press Enter to finish:")

while True:
    user_input = input(f"Enter temperature {len(temperatures)+1}: ")
    if user_input == "":
        break
    try:
        temp = float(user_input.rstrip('Cc'))
        temperatures.append(temp)
    except ValueError:
        print("Invalid input! Please enter a number (e.g., 25C).")
# Out:
# Enter temperatures in Celsius (e.g., 25C). Press Enter to finish:
# Enter temperature 1:  30C
# Enter temperature 2:  28C
# Enter temperature 3:  26C
# Enter temperature 4:  29C
# Enter temperature 5:  30C
# Enter temperature 6:

# %%
if not temperatures:
    print("No temperature readings were entered!")
else:
    maximum_temp = max(temperatures)
    minimum_temp = min(temperatures)
    mean_temp = statistics.mean(temperatures)

    print(f"\nMaximum temperature: {maximum_temp}C")
    print(f"Minimum temperature: {minimum_temp}C")
    print(f"Mean temperature: {mean_temp:.2f}C")
# Out:
# Maximum temperature: 30.0C
# Minimum temperature: 26.0C
# Mean temperature: 28.60C
